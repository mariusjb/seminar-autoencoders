# %%
import torch
import matplotlib.pyplot as plt

# Assuming wae_mmd is your trained WAE model
def generate_samples(model_path, num_samples):
    # Load the model
    wae_mmd = WAE_MMD(latent_dim=64, input_dim=784, device='cpu')

    wae_mmd.load_state_dict(torch.load(model_path))
    
    # Sample latent vectors from a Gaussian distribution
    z_samples = torch.randn(num_samples, wae_mmd.decoder.latent_dim, device=wae_mmd.device)
    
    # Feed the sampled latent vectors through the decoder
    with torch.no_grad():
        generated_samples = wae_mmd.decoder(z_samples)
    
    return generated_samples

# Generate samples and plot them for each model
def plot_generated_samples(model_paths, num_samples):
    num_models = len(model_paths)
    
    fig, axes = plt.subplots(num_samples, num_models, figsize=(5*num_models, 5*num_samples))
    
    for j, model_path in enumerate(model_paths):
        generated_samples = generate_samples(model_path, num_samples)
        
        for i in range(num_samples):
            sample = generated_samples[i].squeeze().numpy()  # Convert to numpy array
            axes[i, j].imshow(sample, cmap='gray')
            axes[i, j].axis('off')
    
    plt.tight_layout()
    plt.show()

# List of model paths saved at each 1000th batch
model_paths = [f'wae_mmd_{i}000.pt' for i in range(1, 20)]

# Generate and plot samples for each model
num_samples = 10
plot_generated_samples(model_paths, num_samples)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 40
#      38 # Generate and plot samples for each model
#      39 num_samples = 10
# ---> 40 plot_generated_samples(model_paths, num_samples)
#
# Cell In[6], line 25, in plot_generated_samples(model_paths, num_samples)
#      22 fig, axes = plt.subplots(num_samples, num_models, figsize=(5*num_models, 5*num_samples))
#      24 for j, model_path in enumerate(model_paths):
# ---> 25     generated_samples = generate_samples(model_path, num_samples)
#      27     for i in range(num_samples):
#      28         sample = generated_samples[i].squeeze().numpy()  # Convert to numpy array
#
# Cell In[6], line 10, in generate_samples(model_path, num_samples)
#       7 wae_mmd = torch.load(model_path)
#       9 # Sample latent vectors from a Gaussian distribution
# ...

# %%
model_path
